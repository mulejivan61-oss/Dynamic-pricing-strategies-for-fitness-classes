# %%
print("Dynamic Pricing Menternship Started 🚀")
# Out:
# Dynamic Pricing Menternship Started 🚀

# %%
# Out:
# Running cells with 'Python 3.14.5' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/Asus/AppData/Local/Programs/Python/Python314/python.exe -m pip install ipykernel -U --user --force-reinstall'
